# %% [markdown]
# <a href="https://colab.research.google.com/github/refecher/space-missions-analysis/blob/master/Space_Missions_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # An Exploration Analysis on Space Missions Since 1957
#
# <center><img src=https://img-c.udemycdn.com/redactor/raw/assignment/2020-11-01_16-57-32-41f2067132bc0f59fba67ec69e75e916.jpg height=500>
#
# This dataset was scraped from [nextspaceflight.com](https://nextspaceflight.com/launches/past/?page=1) and includes all the space missions since the beginning of Space Missions in 1957!</center>

# %% [markdown]
# # 1. Imports

# %% [markdown]
# ### Install Package that Contains Country Codes

# %%
# %pip install iso3166
# Out:
# Collecting iso3166
#   Downloading iso3166-2.0.2-py3-none-any.whl (8.5 kB)
# Installing collected packages: iso3166
# Successfully installed iso3166-2.0.2

# %% [markdown]
# ### Upgrade Plotly Package

# %%
# %pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Collecting plotly
#   Downloading plotly-5.8.0-py2.py3-none-any.whl (15.2 MB)
#      |████████████████████████████████| 15.2 MB 7.6 MB/s
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# Successfully installed plotly-5.8.0

# %%
# %pip install -U kaleido
# Out:
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      |████████████████████████████████| 79.9 MB 84 kB/s
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %% [markdown]
# ### Import Statements

# %%
import pandas as pd
import plotly.express as px
from iso3166 import countries
import os

# %%
if not os.path.exists("images"):
    os.mkdir("images")

# %% [markdown]
# # 2. Preliminary Data Exploration 🔎

# %% [markdown]
# ### Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Load and Display the Data
# As seen below, the data contains 6315 rows and 7 columns. In this first look, we can see some NaN values in the price column. Let's check if there's more NaN values in the other columns.

# %%
data = pd.read_csv('output.csv', index_col=0)
data
# Out:
#      organisation                                         location  \
# 0          SpaceX         SLC-40, Cape Canaveral SFS, Florida, USA
# 1          SpaceX          SLC-4E, Vandenberg SFB, California, USA
# 2         i-Space  Site 95, Jiuquan Satellite Launch Center, China
# 3            CASC  LC-201, Wenchang Satellite Launch Center, China
# 4          SpaceX       LC-39A, Kennedy Space Center, Florida, USA
# ...           ...                                              ...
# 6310      US Navy         LC-18A, Cape Canaveral SFS, Florida, USA
# 6311         ABMA         LC-26A, Cape Canaveral SFS, Florida, USA
# 6312      US Navy         LC-18A, Cape Canaveral SFS, Florida, USA
# 6313    RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 6314    RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                                 date                                 details  \
# 0       Sat May 14, 2022 3:40 PM CDT  Falcon 9 Block 5 | Starlink Group 4-15
# 1       Fri May 13, 2022 5:07 PM CDT  Falcon 9 Block 5 | Starlink Group 4-13
# 2       Fri May 13, 2022 2:09 AM CDT     Hyperbola-1 | Jilin-1 Mofang-01A(R)
# 3       Mon May 9, 2022 12:56 PM CDT               Long March 7 | Tianzhou 4
# 4        Fri May 6, 2022 4:42 AM CDT  Falcon 9 Block 5 | Starlink Group 4-17
# ...                              ...                                     ...
# 6310   Wed Feb 5, 1958 1:33 AM GMT-6               Vanguard | Vanguard TV3BU
# 6311  Fri Jan 31, 1958 9:47 PM GMT-6                     Juno I | Explorer 1
# 6312  Fri Dec 6, 1957 10:44 AM GMT-6                 Vanguard | Vanguard TV3
# 6313   Sat Nov 2, 1957 8:30 PM GMT-6              Sputnik 8K71PS | Sputnik 2
# 6314   Fri Oct 4, 1957 2:28 PM GMT-5              Sputnik 8K71PS | Sputnik 1
#
#      price_in_million mission_status rocket_status
# 0       $67.0 million        Success        Active
# 1       $67.0 million        Success        Active
# 2                 NaN        Failure        Active
# 3                 NaN        Success        Active
# 4       $67.0 million        Success        Active
# ...               ...            ...           ...
# 6310              NaN        Failure       Retired
# 6311              NaN        Success       Retired
# 6312              NaN        Failure       Retired
# 6313              NaN        Success       Retired
# 6314              NaN        Success       Retired
#
# [6315 rows x 7 columns]

# %% [markdown]
# ###Gathering General Information
# The table below shows us that we have a total of 7 columns and only one of the columns has missing values.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6315 entries, 0 to 6314
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   organisation      6315 non-null   object
#  1   location          6315 non-null   object
#  2   date              6315 non-null   object
#  3   details           6315 non-null   object
#  4   price_in_million  2325 non-null   object
#  5   mission_status    6315 non-null   object
#  6   rocket_status     6315 non-null   object
# dtypes: object(7)
# memory usage: 394.7+ KB

# %% [markdown]
# ###Check for Nulls and Duplicates
# The database has no duplicate rows, but there are a total of 3990 Null values in one column, which is more than 60% of the total values for that column missing.

# %%
print(f'Are there any NaN values?  {data.isnull().values.any()}')
print(f'Are there any duplicate values?  {data.duplicated().values.any()}')
# Out:
# Are there any NaN values?  True
# Are there any duplicate values?  False

# %%
percent_missing = (data.isnull().sum() * 100) / len(data)
percent_missing_df = pd.DataFrame({'column': data.columns,
                                 'percent': percent_missing})
percent_missing_df.reset_index(drop=True, inplace=True)
percent_missing_df = percent_missing_df[percent_missing_df['percent']>0]
percent_missing_df
# Out:
#              column  percent
# 4  price_in_million    63.18

# %% [markdown]
# # 3. Data Cleaning 🧹

# %% [markdown]
# ###Convert 'Date' Column and Create 'Year' Column
# I perform data preprocessing by conveting the 'date' column to a datetime object. After, from this column, I extract a 'year' column.

# %%
data['date'] = data['date'].str.replace('CST|CDT', '', regex=True)
data['date'] = pd.to_datetime(data['date'], utc=True).dt.tz_convert('America/Chicago')
data['year'] = pd.DatetimeIndex(data['date']).year
data
# Out:
#      organisation                                         location  \
# 0          SpaceX         SLC-40, Cape Canaveral SFS, Florida, USA
# 1          SpaceX          SLC-4E, Vandenberg SFB, California, USA
# 2         i-Space  Site 95, Jiuquan Satellite Launch Center, China
# 3            CASC  LC-201, Wenchang Satellite Launch Center, China
# 4          SpaceX       LC-39A, Kennedy Space Center, Florida, USA
# ...           ...                                              ...
# 6310      US Navy         LC-18A, Cape Canaveral SFS, Florida, USA
# 6311         ABMA         LC-26A, Cape Canaveral SFS, Florida, USA
# 6312      US Navy         LC-18A, Cape Canaveral SFS, Florida, USA
# 6313    RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 6314    RVSN USSR        Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                           date                                 details  \
# 0    2022-05-14 10:40:00-05:00  Falcon 9 Block 5 | Starlink Group 4-15
# 1    2022-05-13 12:07:00-05:00  Falcon 9 Block 5 | Starlink Group 4-13
# 2    2022-05-12 21:09:00-05:00     Hyperbola-1 | Jilin-1 Mofang-01A(R)
# 3    2022-05-09 07:56:00-05:00               Long March 7 | Tianzhou 4
# 4    2022-05-05 23:42:00-05:00  Falcon 9 Block 5 | Starlink Group 4-17
# ...                        ...                                     ...
# 6310 1958-02-04 13:33:00-06:00               Vanguard | Vanguard TV3BU
# 6311 1958-01-31 09:47:00-06:00                     Juno I | Explorer 1
# 6312 1957-12-05 22:44:00-06:00                 Vanguard | Vanguard TV3
# 6313 1957-11-02 08:30:00-06:00              Sputnik 8K71PS | Sputnik 2
# 6314 1957-10-04 04:28:00-05:00              Sputnik 8K71PS | Sputnik 1
#
#      price_in_million mission_status rocket_status  year
# 0       $67.0 million        Success        Active  2022
# 1       $67.0 million        Success        Active  2022
# 2                 NaN        Failure        Active  2022
# 3                 NaN        Success        Active  2022
# 4       $67.0 million        Success        Active  2022
# ...               ...            ...           ...   ...
# 6310              NaN        Failure       Retired  1958
# 6311              NaN        Success       Retired  1958
# 6312              NaN        Failure       Retired  1957
# 6313              NaN        Success       Retired  1957
# 6314              NaN        Success       Retired  1957
#
# [6315 rows x 8 columns]

# %% [markdown]
# ###Create 'Country' Column and Substitute Wrong Values
# Here, I extract the 'country' from the 'location' column. By doing that, I realize that some countries are wrong, so I fix that by replacing it for the correct country name.

# %%
data[['location', 'country']] = data['location'].str.rsplit(', ', 1, expand=True)
data
# Out:
#      organisation                                  location  \
# 0          SpaceX       SLC-40, Cape Canaveral SFS, Florida
# 1          SpaceX        SLC-4E, Vandenberg SFB, California
# 2         i-Space  Site 95, Jiuquan Satellite Launch Center
# 3            CASC  LC-201, Wenchang Satellite Launch Center
# 4          SpaceX     LC-39A, Kennedy Space Center, Florida
# ...           ...                                       ...
# 6310      US Navy       LC-18A, Cape Canaveral SFS, Florida
# 6311         ABMA       LC-26A, Cape Canaveral SFS, Florida
# 6312      US Navy       LC-18A, Cape Canaveral SFS, Florida
# 6313    RVSN USSR             Site 1/5, Baikonur Cosmodrome
# 6314    RVSN USSR             Site 1/5, Baikonur Cosmodrome
#
#                           date                                 details  \
# 0    2022-05-14 10:40:00-05:00  Falcon 9 Block 5 | Starlink Group 4-15
# 1    2022-05-13 12:07:00-05:00  Falcon 9 Block 5 | Starlink Group 4-13
# 2    2022-05-12 21:09:00-05:00     Hyperbola-1 | Jilin-1 Mofang-01A(R)
# 3    2022-05-09 07:56:00-05:00               Long March 7 | Tianzhou 4
# 4    2022-05-05 23:42:00-05:00  Falcon 9 Block 5 | Starlink Group 4-17
# ...                        ...                                     ...
# 6310 1958-02-04 13:33:00-06:00               Vanguard | Vanguard TV3BU
# 6311 1958-01-31 09:47:00-06:00                     Juno I | Explorer 1
# 6312 1957-12-05 22:44:00-06:00                 Vanguard | Vanguard TV3
# 6313 1957-11-02 08:30:00-06:00              Sputnik 8K71PS | Sputnik 2
# 6314 1957-10-04 04:28:00-05:00              Sputnik 8K71PS | Sputnik 1
#
#      price_in_million mission_status rocket_status  year     country
# 0       $67.0 million        Success        Active  2022         USA
# 1       $67.0 million        Success        Active  2022         USA
# 2                 NaN        Failure        Active  2022       China
# 3                 NaN        Success        Active  2022       China
# 4       $67.0 million        Success        Active  2022         USA
# ...               ...            ...           ...   ...         ...
# 6310              NaN        Failure       Retired  1958         USA
# 6311              NaN        Success       Retired  1958         USA
# 6312              NaN        Failure       Retired  1957         USA
# 6313              NaN        Success       Retired  1957  Kazakhstan
# 6314              NaN        Success       Retired  1957  Kazakhstan
#
# [6315 rows x 9 columns]

# %%
data.country.unique()
# Out:
# array(['USA', 'China', 'New Zealand', 'Yellow Sea', 'Russia',
#        'Kazakhstan', 'Iran', 'India', 'France', 'Japan', 'South Korea',
#        'Israel', 'North Korea', 'Pacific Missile Range Facility',
#        'Pacific Ocean', 'Marshall Islands', 'Barents Sea', 'Brazil',
#        'Gran Canaria', 'Kenya', 'Australia'], dtype=object)

# %%
countries_dict = {
    'Russia' : 'Russian Federation',
    'Barents Sea': 'Russian Federation',
    'Yellow Sea': 'China',
    'Shahrud Missile Test Site': 'Iran',
    'Pacific Missile Range Facility': 'USA',
    'New Mexico' : 'USA',
    'Gran Canaria': 'USA'
}

data['country'] = data['country'].replace(countries_dict)

# %%
data.country.unique()
# Out:
# array(['USA', 'China', 'New Zealand', 'Russian Federation', 'Kazakhstan',
#        'Iran', 'India', 'France', 'Japan', 'South Korea', 'Israel',
#        'North Korea', 'Pacific Ocean', 'Marshall Islands', 'Brazil',
#        'Kenya', 'Australia'], dtype=object)

# %% [markdown]
# ### Clean Price Column
# Here, I decided that the price column would be better if it contained only numbers, so I removed all the unecessary characteres and multiplied the numbers to get the price of the rocket.

# %%
data['price_in_million'] = data['price_in_million'].astype(str).str.replace(r'\D+', '', regex=True)
data['price_in_million'] = pd.to_numeric(data['price_in_million']).apply(lambda x: x*100000)
data
# Out:
#      organisation                                  location  \
# 0          SpaceX       SLC-40, Cape Canaveral SFS, Florida
# 1          SpaceX        SLC-4E, Vandenberg SFB, California
# 2         i-Space  Site 95, Jiuquan Satellite Launch Center
# 3            CASC  LC-201, Wenchang Satellite Launch Center
# 4          SpaceX     LC-39A, Kennedy Space Center, Florida
# ...           ...                                       ...
# 6310      US Navy       LC-18A, Cape Canaveral SFS, Florida
# 6311         ABMA       LC-26A, Cape Canaveral SFS, Florida
# 6312      US Navy       LC-18A, Cape Canaveral SFS, Florida
# 6313    RVSN USSR             Site 1/5, Baikonur Cosmodrome
# 6314    RVSN USSR             Site 1/5, Baikonur Cosmodrome
#
#                           date                                 details  \
# 0    2022-05-14 10:40:00-05:00  Falcon 9 Block 5 | Starlink Group 4-15
# 1    2022-05-13 12:07:00-05:00  Falcon 9 Block 5 | Starlink Group 4-13
# 2    2022-05-12 21:09:00-05:00     Hyperbola-1 | Jilin-1 Mofang-01A(R)
# 3    2022-05-09 07:56:00-05:00               Long March 7 | Tianzhou 4
# 4    2022-05-05 23:42:00-05:00  Falcon 9 Block 5 | Starlink Group 4-17
# ...                        ...                                     ...
# 6310 1958-02-04 13:33:00-06:00               Vanguard | Vanguard TV3BU
# 6311 1958-01-31 09:47:00-06:00                     Juno I | Explorer 1
# 6312 1957-12-05 22:44:00-06:00                 Vanguard | Vanguard TV3
# 6313 1957-11-02 08:30:00-06:00              Sputnik 8K71PS | Sputnik 2
# 6314 1957-10-04 04:28:00-05:00              Sputnik 8K71PS | Sputnik 1
#
#       price_in_million mission_status rocket_status  year     country
# 0        67,000,000.00        Success        Active  2022         USA
# 1        67,000,000.00        Success        Active  2022         USA
# 2                  NaN        Failure        Active  2022       China
# 3                  NaN        Success        Active  2022       China
# 4        67,000,000.00        Success        Active  2022         USA
# ...                ...            ...           ...   ...         ...
# 6310               NaN        Failure       Retired  1958         USA
# 6311               NaN        Success       Retired  1958         USA
# 6312               NaN        Failure       Retired  1957         USA
# 6313               NaN        Success       Retired  1957  Kazakhstan
# 6314               NaN        Success       Retired  1957  Kazakhstan
#
# [6315 rows x 9 columns]

# %% [markdown]
# # 4. Data Analysis 🤯

# %%
def plot_graph(dataframe, title, x_title, i):
  graph = px.bar(x = dataframe.index,
                 y = dataframe.values,
                 title=title,
                 hover_name=dataframe.index,
                 color=dataframe.values,
                 color_continuous_scale=px.colors.qualitative.Pastel)
  graph.update_layout(xaxis_title=x_title,
                    yaxis_title='Number of Rockets',
                    coloraxis_showscale=False)

  graph.write_image(f"images/fig{i}.png")
  graph.show()

# %% [markdown]
# ###Data Visualization (Year)
#
# The graph below represent the number of launches per year from 1957 to 2022.
#
# 2020, 1967 and 1966 are the years with the highest number of rockets launched with 157, 140, and 136 total of launches for these years.

# %%
year = data['year'].value_counts()
plot_graph(year, 'Number of Rockets Launched by Year', 'Year', 1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="72b068ec-82c1-4035-a999-58ff4f1d20ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72b068ec-82c1-4035-a999-58ff4f1d20ce")) {                    Plotly.newPlot(                        "72b068ec-82c1-4035-a999-58ff4f1d20ce",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","hovertext":[2021.0,1967.0,1966.0,1971.0,1975.0,1968.0,1984.0,1976.0,1977.0,1983.0,1982.0,1978.0,1969.0,1965.0,1981.0,1970.0,1985.0,1988.0,1990.0,2018.0,2020.0,1973.0,1987.0,1972.0,1974.0,1986.0,1979.0,1980.0,2019.0,1989.0,1964.0,1992.0,2014.0,1991.0,1994.0,2017.0,2016.0,2015.0,1997.0,2000.0,1993.0,1962.0,2011.0,2013.0,1998.0,1995.0,2009.0,1999.0,2012.0,1996.0,2010.0,1963.0,2008.0,2007.0,2006.0,2002.0,2003.0,2001.0,2004.0,1961.0,2022.0,2005.0,1960.0,1958.0,1959.0,1957.0],"legendgroup":"","marker":{"color":[157,140,136,134,132,131,131,131,131,130,129,129,127,126,126,126,126,122,121,120,118,118,116,115,114,111,110,109,107,103,100,97,96,93,93,92,90,89,89,85,84,84,84,83,82,80,79,78,78,77,74,71,69,68,66,65,64,59,58,56,55,55,41,28,24,3],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2021,1967,1966,1971,1975,1968,1984,1976,1977,1983,1982,1978,1969,1965,1981,1970,1985,1988,1990,2018,2020,1973,1987,1972,1974,1986,1979,1980,2019,1989,1964,1992,2014,1991,1994,2017,2016,2015,1997,2000,1993,1962,2011,2013,1998,1995,2009,1999,2012,1996,2010,1963,2008,2007,2006,2002,2003,2001,2004,1961,2022,2005,1960,1958,1959,1957],"xaxis":"x","y":[157,140,136,134,132,131,131,131,131,130,129,129,127,126,126,126,126,122,121,120,118,118,116,115,114,111,110,109,107,103,100,97,96,93,93,92,90,89,89,85,84,84,84,83,82,80,79,78,78,77,74,71,69,68,66,65,64,59,58,56,55,55,41,28,24,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...

# %% [markdown]
# ###Data Visualization (Country)
#
# The graph below represent the number of launches per country over the years.
#
# Russian Federation and the USA are the countries with the biggest number of rockets launched since 1957.

# %%
country = data['country'].value_counts()
plot_graph(country, 'Number of Rockets Launched by Country', 'Country', 2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="bf19ad1d-dc78-450b-95ae-989a642d824b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf19ad1d-dc78-450b-95ae-989a642d824b")) {                    Plotly.newPlot(                        "bf19ad1d-dc78-450b-95ae-989a642d824b",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","hovertext":["USA","Russian Federation","Kazakhstan","China","France","Japan","India","Pacific Ocean","New Zealand","Iran","Israel","Marshall Islands","Kenya","Australia","North Korea","South Korea","Brazil"],"legendgroup":"","marker":{"color":[1871,1795,1539,460,316,127,80,36,26,16,13,9,9,6,5,4,3],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["USA","Russian Federation","Kazakhstan","China","France","Japan","India","Pacific Ocean","New Zealand","Iran","Israel","Marshall Islands","Kenya","Australia","North Korea","South Korea","Brazil"],"xaxis":"x","y":[1871,1795,1539,460,316,127,80,36,26,16,13,9,9,6,5,4,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"typ ...

# %% [markdown]
# ###Data Visualization (Organisation)
# The organisation with the biggest number of rockets launched is the RVSN USSR. This organisation was created as a part of the Soviet Armed Forces in 1959. After the Soviet Union collapsed in 1991, their launches are attributed to Russian Federation and Kazakhstan.

# %%
organization = data['organisation'].value_counts()
plot_graph(organization, 'Number of Rockets Launched by Organisation', 'Organisation', 3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="850c09ba-c07c-4e3a-817a-1ce24407fbe3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("850c09ba-c07c-4e3a-817a-1ce24407fbe3")) {                    Plotly.newPlot(                        "850c09ba-c07c-4e3a-817a-1ce24407fbe3",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","hovertext":["RVSN USSR","US Air Force","CASC","Roscosmos","VKS RF","Arianespace","General Dynamics","NASA","SpaceX","ULA","Boeing","ILS","Martin Marietta","Northrop","MHI","ISRO","Lockheed","Starsem","Sea Launch","ISAS","Rocket Lab","Kosmotras","Blue Origin","ABMA","US Navy","ExPace","ISA","IAI","Eurockot","ESA","Virgin Galactic","ASI","JAXA","CNES","MITT","Astra","Land Launch","UT","CASIC","KCST","Virgin Orbit","Arm\u00e9e de l'Air","i-Space","CECLES","KARI","SRC","Scaled Composite","AEB","IRGC","RAE","OKB-586","Galactic Energy","GK LS","Firefly","Sandia","EER","OneSpace","Landspace","Douglas"],"legendgroup":"","marker":{"color":[2477,548,432,346,324,290,251,221,168,149,138,137,114,89,84,80,79,37,36,30,26,22,20,17,17,15,14,13,13,13,12,9,8,8,7,6,6,5,5,5,4,4,4,4,4,3,3,3,2,2,2,2,1,1,1,1,1,1,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["RVSN USSR","US Air Force","CASC","Roscosmos","VKS RF","Arianespace","General Dynamics","NASA","SpaceX","ULA","Boeing","ILS","Martin Marietta","Northrop","MHI","ISRO","Lockheed","Starsem","Sea Launch","ISAS","Rocket Lab","Kosmotras","Blue Origin","ABMA","US Navy","ExPace","ISA","IAI","Eurockot","ESA","Virgin Galactic","ASI","JAXA","CNES","MITT","Astra","Land Launch","UT","CASIC","KCST","Virgin Orbit","Arm\u00e9e de l'Air","i-Space","CECLES","KARI","SRC","Scaled Composite","AEB","IRGC","RAE","OKB-586","Galactic Energy","GK LS","Firefly","Sandia","EER","OneSpace","Landspace","Douglas"],"xaxis":"x","y":[2477,548,432,346,324,290,251,221,168,149,138,137,114,89,84,80,79,37,36,30,26,22,20,17,17,15,14,13,13,13,12,9,8,8,7,6,6,5,5,5,4,4,4,4,4,3,3,3,2,2,2,2,1,1,1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888 ...

# %% [markdown]
# # 4. Distribution of Missions and Rockets

# %%
def plot_pie(dataframe, target_column, title, i):
  pie_df = dataframe[target_column].value_counts()
  graph = px.pie(
      pie_df,
      values=pie_df.values,
      names=pie_df.index,
      title=title,
      color_discrete_sequence=px.colors.qualitative.Pastel
  )
  graph.update_traces(textinfo='percent+label')

  graph.write_image(f"images/fig{i}.png")
  graph.show()

# %% [markdown]
# ### Status of Rockets Launched
# Analyzing the graph below, we see that more than 80% of the rockets launched have been retired.

# %%
plot_pie(data, 'rocket_status', 'Status of Rockets Launched', 4)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="758ef204-fdeb-445b-9869-aabae5ea79ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("758ef204-fdeb-445b-9869-aabae5ea79ae")) {                    Plotly.newPlot(                        "758ef204-fdeb-445b-9869-aabae5ea79ae",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["Retired","Active"],"legendgroup":"","name":"","showlegend":true,"values":[5126,1189],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":" ...

# %% [markdown]
# ### Status of Missions
# More than 90% of the missions were successfull.

# %%
plot_pie(data, 'mission_status', 'Status of Missions', 5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="c6b087ee-91df-4b95-95df-34b50f29e07f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6b087ee-91df-4b95-95df-34b50f29e07f")) {                    Plotly.newPlot(                        "c6b087ee-91df-4b95-95df-34b50f29e07f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["Success","Failure","Partial Failure","Prelaunch Failure"],"legendgroup":"","name":"","showlegend":true,"values":[5760,436,111,8],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"hi ...

# %% [markdown]
# # 5. Number of Launches by Country
# To plot the graph, we first need to get the code for each country.
#
# The launches made by Sea Launch weren't attributed to any country because Sea Launch is a consortium of four companies from Norway, Russia, Ukraine and the United States. It was formed to launch the Zenit family of rockets from the Odyssey floating launch platform located in the Pacific Ocean.

# %%
country_dict = {}
for c in countries:
    country_dict[c.name] = c.alpha3
    
data['alpha3'] = data['country']
df = data.replace({"alpha3": country_dict})
df
# Out:
#      organisation                                  location  \
# 0          SpaceX       SLC-40, Cape Canaveral SFS, Florida
# 1          SpaceX        SLC-4E, Vandenberg SFB, California
# 2         i-Space  Site 95, Jiuquan Satellite Launch Center
# 3            CASC  LC-201, Wenchang Satellite Launch Center
# 4          SpaceX     LC-39A, Kennedy Space Center, Florida
# ...           ...                                       ...
# 6310      US Navy       LC-18A, Cape Canaveral SFS, Florida
# 6311         ABMA       LC-26A, Cape Canaveral SFS, Florida
# 6312      US Navy       LC-18A, Cape Canaveral SFS, Florida
# 6313    RVSN USSR             Site 1/5, Baikonur Cosmodrome
# 6314    RVSN USSR             Site 1/5, Baikonur Cosmodrome
#
#                           date                                 details  \
# 0    2022-05-14 10:40:00-05:00  Falcon 9 Block 5 | Starlink Group 4-15
# 1    2022-05-13 12:07:00-05:00  Falcon 9 Block 5 | Starlink Group 4-13
# 2    2022-05-12 21:09:00-05:00     Hyperbola-1 | Jilin-1 Mofang-01A(R)
# 3    2022-05-09 07:56:00-05:00               Long March 7 | Tianzhou 4
# 4    2022-05-05 23:42:00-05:00  Falcon 9 Block 5 | Starlink Group 4-17
# ...                        ...                                     ...
# 6310 1958-02-04 13:33:00-06:00               Vanguard | Vanguard TV3BU
# 6311 1958-01-31 09:47:00-06:00                     Juno I | Explorer 1
# 6312 1957-12-05 22:44:00-06:00                 Vanguard | Vanguard TV3
# 6313 1957-11-02 08:30:00-06:00              Sputnik 8K71PS | Sputnik 2
# 6314 1957-10-04 04:28:00-05:00              Sputnik 8K71PS | Sputnik 1
#
#       price_in_million mission_status rocket_status  year     country alpha3
# 0        67,000,000.00        Success        Active  2022         USA    USA
# 1        67,000,000.00        Success        Active  2022         USA    USA
# 2                  NaN        Failure        Active  2022       China    CHN
# 3                  NaN        Success        Active  2022       China    CHN
# 4        67,000,000.00        Success        Active  2022         USA    USA
# ...                ...            ...           ...   ...         ...    ...
# 6310               NaN        Failure       Retired  1958         USA    USA
# 6311               NaN        Success       Retired  1958         USA    USA
# 6312               NaN        Failure       Retired  1957         USA    USA
# 6313               NaN        Success       Retired  1957  Kazakhstan    KAZ
# 6314               NaN        Success       Retired  1957  Kazakhstan    KAZ
#
# [6315 rows x 10 columns]

# %%
df.loc[df['country'] == 'Pacific Ocean']
# Out:
#      organisation                            location  \
# 892    Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1002   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1013   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1038   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1053   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1115   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1300   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1344   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1356   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1367   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1378   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1390   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1456   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1473   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1488   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1501   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1514   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1522   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1533   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1556   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1565   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1572   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1613   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1622   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1637   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1656   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1668   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1676   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1737   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1808   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1814   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1843   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1866   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1895   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1931   Sea Launch  LP Odyssey, Kiritimati Launch Area
# 1975   Sea Launch  LP Odyssey, Kiritimati Launch Area
#
#                           date                           details  \
# 892  2014-05-26 11:09:00-05:00          Zenit-3 SL | Eutelsat 3B
# 1002 2013-01-31 18:55:00-06:00          Zenit-3 SL | Intelsat 27
# 1013 2012-12-03 08:43:00-06:00         Zenit-3 SL | Eutelsat-70B
# 1038 2012-08-18 20:54:00-05:00          Zenit-3 SL | Intelsat 21
# 1053 2012-05-31 19:22:00-05:00          Zenit-3 SL | Intelsat 19
# 1115 2011-09-24 10:17:00-05:00      Zenit-3 SL | Atlantic Bird 7
# 1300 2009-04-19 22:15:00-05:00            Zenit-3 SL | Sicral-1B
# 1344 2008-09-23 23:27:00-05:00            Zenit-3 SL | Galaxy 19
# 1356 2008-07-15 19:20:00-05:00          Zenit-3 SL | EchoStar XI
# 1367 2008-05-20 23:43:00-05:00            Zenit-3 SL | Galaxy 18
# 1378 2008-03-19 12:47:00-05:00           Zenit-3 SL | DirecTV-11
# 1390 2008-01-14 23:48:00-06:00            Zenit-3 SL | Thuraya-3
# 1456 2007-01-30 11:21:00-06:00                Zenit-3 SL | NSS-8
# 1473 2006-10-30 11:48:00-06:00                 Zenit-3 SL | XM-4
# 1488 2006-08-21 17:26:00-05:00           Zenit-3 SL | Koreasat 5
# 1501 2006-06-17 21:49:00-05:00            Zenit-3 SL | Galaxy 16
# 1514 2006-04-12 13:29:00-05:00              Zenit-3 SL | JCSat-9
# 1522 2006-02-15 10:34:00-06:00           Zenit-3 SL | EchoStar-X
# 1533 2005-11-08 02:06:00-06:00        Zenit-3 SL | Inmarsat 4F-2
# 1556 2005-06-23 04:02:00-05:00  Zenit-3 SL | Intelsat-Americas 8
# 1565 2005-04-25 21:31:00-05:00           Zenit-3 SL | Spaceway-1
# 1572 2005-02-28 15:50:00-06:00                 Zenit-3 SL | XM-3
# 1613 2004-06-28 17:58:00-05:00           Zenit-3 SL | Telstar 18
# 1622 2004-05-04 02:41:00-05:00           Zenit-3 SL | DirecTV-7S
# 1637 2004-01-10 16:12:00-06:00           Zenit-3 SL | Telstar 14
# 1656 2003-09-30 18:02:00-05:00            Zenit-3 SL | Galaxy-13
# 1668 2003-08-07 17:30:00-05:00           Zenit-3 SL | EchoStar 9
# 1676 2003-06-10 03:55:00-05:00            Zenit-3 SL | Thuraya-2
# 1737 2002-06-15 12:39:00-05:00          Zenit-3 SL | Galaxy IIIC
# 1808 2001-05-08 12:10:00-05:00                 Zenit-3 SL | XM-1
# 1814 2001-03-18 10:33:00-06:00                 Zenit-3 SL | XM-2
# 1843 2000-10-20 19:51:00-05:00            Zenit-3 SL | Thuraya 1
# 1866 2000-07-28 12:41:00-05:00                Zenit-3 SL | PAS 9
# 1895 2000-03-12 02:49:00-06:00              Zenit-3 SL | ICO F-1
# 1931 1999-10-09 17:28:00-05:00           Zenit-3 SL | DirecTV 1R
# 1975 1999-03-27 13:29:00-06:00              Zenit-3 SL | DemoSat
#
#       price_in_million   mission_status rocket_status  year        country  \
# 892                NaN          Success       Retired  2014  Pacific Ocean
# 1002               NaN          Failure       Retired  2013  Pacific Ocean
# 1013               NaN          Success       Retired  2012  Pacific Ocean
# 1038               NaN          Success       Retired  2012  Pacific Ocean
# 1053               NaN          Success       Retired  2012  Pacific Ocean
# 1115               NaN          Success       Retired  2011  Pacific Ocean
# 1300               NaN          Success       Retired  2009  Pacific Ocean
# 1344               NaN          Success       Retired  2008  Pacific Ocean
# 1356               NaN          Success       Retired  2008  Pacific Ocean
# 1367               NaN          Success       Retired  2008  Pacific Ocean
# 1378               NaN          Success       Retired  2008  Pacific Ocean
# 1390               NaN          Success       Retired  2008  Pacific Ocean
# 1456               NaN          Failure       Retired  2007  Pacific Ocean
# 1473               NaN          Success       Retired  2006  Pacific Ocean
# 1488               NaN          Success       Retired  2006  Pacific Ocean
# 1501               NaN          Success       Retired  2006  Pacific Ocean
# 1514               NaN          Success       Retired  2006  Pacific Ocean
# 1522               NaN          Success       Retired  2006  Pacific Ocean
# 1533               NaN          Success       Retired  2005  Pacific Ocean
# 1556               NaN          Success       Retired  2005  Pacific Ocean
# 1565               NaN          Success       Retired  2005  Pacific Ocean
# 1572               NaN          Success       Retired  2005  Pacific Ocean
# 1613               NaN  Partial Failure       Retired  2004  Pacific Ocean
# 1622               NaN          Success       Retired  2004  Pacific Ocean
# 1637               NaN          Success       Retired  2004  Pacific Ocean
# 1656               NaN          Success       Retired  2003  Pacific Ocean
# 1668               NaN          Success       Retired  2003  Pacific Ocean
# 1676               NaN          Success       Retired  2003  Pacific Ocean
# 1737               NaN          Success       Retired  2002  Pacific Ocean
# 1808               NaN          Success       Retired  2001  Pacific Ocean
# 1814               NaN          Success       Retired  2001  Pacific Ocean
# 1843               NaN          Success       Retired  2000  Pacific Ocean
# 1866               NaN          Success       Retired  2000  Pacific Ocean
# 1895               NaN          Failure       Retired  2000  Pacific Ocean
# 1931               NaN          Success       Retired  1999  Pacific Ocean
# 1975               NaN          Success       Retired  1999  Pacific Ocean
#
#              alpha3
# 892   Pacific Ocean
# 1002  Pacific Ocean
# 1013  Pacific Ocean
# 1038  Pacific Ocean
# 1053  Pacific Ocean
# 1115  Pacific Ocean
# 1300  Pacific Ocean
# 1344  Pacific Ocean
# 1356  Pacific Ocean
# 1367  Pacific Ocean
# 1378  Pacific Ocean
# 1390  Pacific Ocean
# 1456  Pacific Ocean
# 1473  Pacific Ocean
# 1488  Pacific Ocean
# 1501  Pacific Ocean
# 1514  Pacific Ocean
# 1522  Pacific Ocean
# 1533  Pacific Ocean
# 1556  Pacific Ocean
# 1565  Pacific Ocean
# 1572  Pacific Ocean
# 1613  Pacific Ocean
# 1622  Pacific Ocean
# 1637  Pacific Ocean
# 1656  Pacific Ocean
# 1668  Pacific Ocean
# 1676  Pacific Ocean
# 1737  Pacific Ocean
# 1808  Pacific Ocean
# 1814  Pacific Ocean
# 1843  Pacific Ocean
# 1866  Pacific Ocean
# 1895  Pacific Ocean
# 1931  Pacific Ocean
# 1975  Pacific Ocean

# %% [markdown]
# ### Maps

# %%
def plot_map(dataframe, target_column, title, i, width=800, height=600):
    mapdf = dataframe.groupby(['country', 'alpha3'])[target_column].count().reset_index()
    fig = px.choropleth(
        mapdf, 
        locations="alpha3", 
        hover_name="country", 
        color=target_column, 
        projection="natural earth", 
        title=title,
        color_continuous_scale="pinkyl"
    )
    fig.update_layout(title = title, title_x = 0.5)

    fig.write_image(f"images/fig{i}.png")
    fig.show()

# %%
plot_map(df, 'mission_status', 'Number of starts per country', 6)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="92ef865d-3369-4c00-aa8e-77c8e71850b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92ef865d-3369-4c00-aa8e-77c8e71850b0")) {                    Plotly.newPlot(                        "92ef865d-3369-4c00-aa8e-77c8e71850b0",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>alpha3=%{location}<br>mission_status=%{z}<extra></extra>","hovertext":["Australia","Brazil","China","France","India","Iran","Israel","Japan","Kazakhstan","Kenya","Marshall Islands","New Zealand","North Korea","Pacific Ocean","Russian Federation","South Korea","USA"],"locations":["AUS","BRA","CHN","FRA","IND","Iran","ISR","JPN","KAZ","KEN","MHL","NZL","North Korea","Pacific Ocean","RUS","South Korea","USA"],"name":"","z":[6,3,460,316,80,16,13,127,1539,9,9,26,5,36,1795,4,1871],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"li ...

# %%
fail_df = df[df['mission_status'] == 'Failure']
plot_map(fail_df, 'mission_status', 'Number of failures per country', 7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="fb930f85-bb20-43b7-84b7-5c5e9656eb83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb930f85-bb20-43b7-84b7-5c5e9656eb83")) {                    Plotly.newPlot(                        "fb930f85-bb20-43b7-84b7-5c5e9656eb83",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>alpha3=%{location}<br>mission_status=%{z}<extra></extra>","hovertext":["Australia","Brazil","China","France","India","Iran","Israel","Japan","Kazakhstan","Marshall Islands","New Zealand","North Korea","Pacific Ocean","Russian Federation","South Korea","USA"],"locations":["AUS","BRA","CHN","FRA","IND","Iran","ISR","JPN","KAZ","MHL","NZL","North Korea","Pacific Ocean","RUS","South Korea","USA"],"name":"","z":[4,2,25,14,9,8,4,11,113,3,3,3,3,72,3,159],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","widt ...

# %% [markdown]
# ### Analyzing Percent of Successes and Failures for USA and Russia
# Since USA and Russia are the 2 countries with the most number of launches, I decided to analyze their data a bit further. With this analysis, we observe that, even if the USA is the number 1 in number of launches, Russia has more succeeded missions than the USA.

# %%
# Create dataframe with mission_status by country
df1 = df.groupby(['country', 
                  'mission_status']).size().reset_index(name='counts')

# Create USA dataframe
usa_df = df1[df1['country'] == 'USA'].copy()
del usa_df['country']
usa_df['counts'] = (usa_df['counts'] / 
                    usa_df['counts'].sum()) * 100
usa_df.rename(columns = {'counts':'USA_pct'}, 
              inplace = True)

# Create Russia dataframe
russia_df = df1[df1['country'] == 'Russian Federation'].copy()
del russia_df['country']
russia_df['counts'] = (russia_df['counts'] / 
                       russia_df['counts'].sum()) * 100
russia_df.rename(columns = {'counts':'Russia_pct'}, 
                 inplace = True)

# Merge dataframes
merged_df = usa_df.merge(russia_df, on='mission_status')
merged_df.sort_values('USA_pct', axis = 0, ascending = False)
# Out:
#       mission_status  USA_pct  Russia_pct
# 3            Success    89.42       94.15
# 0            Failure     8.50        4.01
# 1    Partial Failure     2.03        1.78
# 2  Prelaunch Failure     0.05        0.06

# %%
newnames = {'USA_pct':'USA', 'Russia_pct': 'Russia'}

graph = px.bar(merged_df, 
               x='mission_status', 
               y=['USA_pct', 'Russia_pct'], 
              #  color=['USA', 'Russia'],
               height=400,
               color_discrete_map={'USA_pct':'#FF6692',
                                   'Russia_pct':'#19D3F3'},
               labels={'mission_status': 'Status of the Missions',
                     'value': 'Percentage',
                     'variable':'Country'})
graph.update_layout(barmode='group',
                    xaxis={'categoryorder':'total descending'})
graph.for_each_trace(lambda t: t.update(name = newnames[t.name],
                                        legendgroup = newnames[t.name],
                                        hovertemplate = t.hovertemplate.replace(t.name, newnames[t.name])))

graph.write_image(f"images/fig8.png")
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="a5498a6b-2e9b-4166-8a54-8f516c9c1d7d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5498a6b-2e9b-4166-8a54-8f516c9c1d7d")) {                    Plotly.newPlot(                        "a5498a6b-2e9b-4166-8a54-8f516c9c1d7d",                        [{"alignmentgroup":"True","hovertemplate":"Country=USA<br>Status of the Missions=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"USA","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"USA","offsetgroup":"USA_pct","orientation":"v","showlegend":true,"textposition":"auto","x":["Failure","Partial Failure","Prelaunch Failure","Success"],"xaxis":"x","y":[8.498129342597542,2.030999465526456,0.053447354355959376,89.41742383752003],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=Russia<br>Status of the Missions=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Russia","marker":{"color":"#19D3F3","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia_pct","orientation":"v","showlegend":true,"textposition":"auto","x":["Failure","Partial Failure","Prelaunch Failure","Success"],"xaxis":"x","y":[4.011142061281337,1.7827298050139277,0.05571030640668524,94.15041782729804],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0, ...

# %% [markdown]
# ### Summary of the Missions Analyses by Countries and Organisations

# %%
df2 = df.groupby(['country', 
                  'organisation', 
                  'mission_status'])['date'].count().reset_index()
df2.rename(columns = {'date':'count'}, inplace = True)

fig = px.sunburst(df2,
                  path=['country', 'organisation', 'mission_status'],
                  values='count',
                  color_discrete_sequence=px.colors.qualitative.Pastel,
                  title='Summary of missions for all countries',
                  width=700,
                  height=700)

fig.write_image("images/fig1.png")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="72a00afa-1c1a-4b8e-9483-fff159965f86" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72a00afa-1c1a-4b8e-9483-fff159965f86")) {                    Plotly.newPlot(                        "72a00afa-1c1a-4b8e-9483-fff159965f86",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["USA/ABMA/Failure","Brazil/AEB/Failure","France/Arianespace/Failure","USA/Astra/Failure","USA/Boeing/Failure","China/CASC/Failure","China/CASIC/Failure","Australia/CECLES/Failure","France/CECLES/Failure","France/CNES/Failure","USA/EER/Failure","France/ESA/Failure","Russian Federation/Eurockot/Failure","China/ExPace/Failure","USA/Firefly/Failure","USA/General Dynamics/Failure","Israel/IAI/Failure","Kazakhstan/ILS/Failure","Iran/ISA/Failure","Japan/ISAS/Failure","India/ISRO/Failure","Japan/JAXA/Failure","South Korea/KARI/Failure","North Korea/KCST/Failure","Kazakhstan/Kosmotras/Failure","China/Landspace/Failure","USA/Lockheed/Failure","Japan/MHI/Failure","Russian Federation/MITT/Failure","USA/Martin Marietta/Failure","USA/NASA/Failure","USA/Northrop/Failure","China/OneSpace/Failure","Australia/RAE/Failure","Kazakhstan/RVSN USSR/Failure","Russian Federation/RVSN USSR/Failure","USA/RVSN USSR/Failure","New Zealand/Rocket Lab/Failure","Kazakhstan/Roscosmos/Failure","Russian Federation/Roscosmos/Failure","Russian Federation/SRC/Failure","USA/Sandia/Failure","Pacific Ocean/Sea Launch/Failure","Marshall Islands/SpaceX/Failure","USA/SpaceX/Failure","USA/US Air Force/Failure","USA/US Navy/Failure","Japan/UT/Failure","Kazakhstan/VKS RF/Failure","Russian Federation/VKS RF/Failure","USA/Virgin Galactic/Failure","USA/Virgin Orbit/Failure","China/i-Space/Failure","USA/ABMA/Partial Failure","France/Arianespace/Partial Failure","France/Arm\u00e9e de l'Air/Partial Failure","USA/Boeing/Partial Failure","China/CASC/Partial Failure","France/ESA/Partial Failure","USA/General Dynamics/Partial Failure","Kazakhstan/ILS/Partial Failure","Japan/ISAS/Partial Failure","India/ISRO/Partial Failure","Japan/MHI/Partial Failure","Russian Federation/MITT/Partial Failure","USA/Martin Marietta/Partial Failure","USA/NASA/Partial Failure","USA/Northrop/Partial Failure","Kazakhstan/RVSN USSR/Partial Failure","Russian Federation/RVSN USSR/Partial Failure","Kazakhstan/Roscosmos/Partial Failure","Pacific Ocean/Sea Launch/Partial Failure","USA/SpaceX/Partial Failure","USA/ULA/Partial Failure","USA/US Air Force/Partial Failure","USA/US Navy/Partial Failure","Russian Federation/VKS RF/Partial Failure","USA/Virgin Galactic/Partial Failure","Brazil/AEB/Prelaunch Failure","Iran/ISA/Prelaunch Failure","Kazakhstan/RVSN USSR/Prelaunch Failure","Russian Federation/RVSN USSR/Prelaunch Failure","USA/SpaceX/Prelaunch Failure","Australia/ABMA/Success","USA/ABMA/Success","Kenya/ASI/Success","France/Arianespace/Success","France/Arm\u00e9e de l'Air/Success","USA/Astra/Success","USA/Blue Origin/Success","USA/Boeing/Success","China/CASC/Success","China/CASIC/Success","France/CNES/Success","USA/Douglas/Success","France/ESA/Success","Russian Federation/Eurockot/Success","China/ExPace/Success","Kazakhstan/GK LS/Success","China/Galactic Energy/Success","USA/General Dynamics/Success","Israel/IAI/Success","Kazakhstan/ILS/Success","USA/ILS/Success","Iran/IRGC/Success","Iran/ISA/Success","Japan/ISAS/Success","India/ISRO/Success","Japan/JAXA/Success","South Korea/KARI/Success","North Korea/KCST/Success","Kazakhstan/Kosmotras/Success","Russian Federation/Kosmotras/Success","Kazakhstan/Land Launch/Success","USA/Lockheed/Success","Japan/MHI/Success","Russian Federation/MITT/Success","USA/Martin M ...
